# %%
import pandas as pd
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

pd.options.display.max_columns = None

# %%
df_no_outliers = pd.read_csv(r"C:\Users\mituc\Ironhack\Curso\IronLabs\California-cleanin\california_no_outliers.csv", index_col = 0)
df_outliers = pd.read_csv(r"C:\Users\mituc\Ironhack\Curso\IronLabs\California-cleanin\california_outliers.csv", index_col = 0)

# %%
df_no_outliers.head(5)
# Out:
#        id state gender  target_d  median_home_val  median_household_income  \
# 0   44060    FL      M     100.0      1158.437751                    392.0
# 1   96093    IL      M       7.0       537.000000                    365.0
# 2   43333    FL      F       5.0       725.000000                    301.0
# 3  190108    FL      F       5.0       995.000000                    252.0
# 4  154301    CA      F      10.0      1026.000000                    459.0
#
#      ic2    ic3    ic4      ic5    avggift  rooms_per_neigh  baths_per_neigh  \
# 0  430.0  466.0  520.0  21975.0  11.626154         1.115880        47.156652
# 1  415.0  410.0  473.0  19387.0   5.666667         1.153659        47.285366
# 2  340.0  361.0  436.0  18837.0   4.111111         1.207756        52.180055
# 3  280.0  316.0  348.0  17991.0   6.000000         1.101266        56.933544
# 4  470.0  491.0  496.0  13803.0  11.250000         1.010183        28.112016
#
#    population_per_household
# ...

# %%
num_no_outliers = df_no_outliers[['median_home_val', 'median_household_income', 'ic2', 'ic3', 'ic4', 'ic5', 'avggift', 'rooms_per_neigh', 'population_per_household', 'baths_per_neigh']]
num_outliers = df_outliers[['median_home_val', 'median_household_income', 'ic2', 'ic3', 'ic4', 'ic5', 'avggift', 'rooms_per_neigh', 'population_per_household', 'baths_per_neigh']]

# %%
columns_no_outliers = num_no_outliers.columns
columns_outliers = num_outliers.columns

# %%
num_no_outliers.hist(bins = 50, figsize = (20,15))
plt.show()

# %%
sns.histplot(num_no_outliers['baths_per_neigh'], bins = 50, kde=True)
# Out:
# <AxesSubplot:xlabel='baths_per_neigh', ylabel='Count'>
